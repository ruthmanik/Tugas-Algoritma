# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthmanik/Tugas-Algoritma/blob/main/2208541028_RUTH%20SANI%20MANIK_TUGAS_VI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5.21 Pandas
#
# Pandas merupakan library pada python yang digunakan pada data analis

# %%
#Tugas Pertemuan Senin,10 April 2023

#yang pertama kita lakukan memanggil library
import pandas as pd

# %%
#memanggil data melalui link github
bunga_csv = pd.read_csv("https://raw.githubusercontent.com/imdwipayana/DATA/main/Bunga%20Iris/bunga_iris.csv")
print(bunga_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#memanggil semua data
bunga_csv
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.1 Membaca File Data pada Pandas
#
# Ada beberapa format file data yang dapat dibaca seperti .csv, .xlsx, .txt

# %%
#memanggil data csv dengan mengupload data dari file pribadi dengan cara menambahkan data di files yang sama
bunga_csv = pd.read_csv("bunga_iris.csv")
print(bunga_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.2 Properti pada Pandas
#
# Pandas memiliki beberapa properti untuk memudahkan melakukan observasi awal tentang data yang baru dipanggil

# %%
#mencetak data yang ingin kita buat
#jika kita tidak mengisi angkanya maka akan sampai no 5
bunga_csv.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#mencetak untuk kolom
print(bunga_csv.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
#mencetak sepal length dalam data
print(bunga_csv["sepal length (cm)"])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
#mencetak data sepal length ke-0
print(bunga_csv["sepal length (cm)"][0])
# Out:
# 5.1

# %%
#mencetak data sepal length ke 1-4
print(bunga_csv["sepal length (cm)"][1:5])
# Out:
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %%
#mencetak data sepal length dan sepal width
#data ke 1-4 
print(bunga_csv[["sepal length (cm)" , "sepal width (cm)"]][1:5])
# Out:
#    sepal length (cm)  sepal width (cm)
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
#mencetak iloc
#"iloc" di panda digunakan untuk memilih baris dan kolom berdasarkan angka,sesuai urutan kemunculannya di bingkai data
#iloc menggunakan integer
#mencetak data kolom 1
print(bunga_csv.iloc[1])
# Out:
# sepal length (cm)    4.9
# sepal width (cm)     3.0
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 1, dtype: float64

# %%
#mencetak iloc
#mencetak data kolom ke 1-4
print(bunga_csv.iloc[1:5])
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#.loc[] merupakan salah satu cara yang efektif untuk memilih baris dan kolom pada dataframe sesuai dengan index baris atau kolom
#mencetak 
print(bunga_csv.loc[bunga_csv["sepal length (cm)"]=="sepal width (cm)"])
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm)]
# Index: []

# %% [markdown]
# # 5.21.3 Mengurutkan data pada Pandas
#
# Data yang telah dipanggil dapat diurutkan mulai dari tinggi ke rendah (atau dari rendah ke tinggi) untuk data berupa angka, sedangkan data berupa string akan diurutkan berdasarkan urutan abjad

# %%
#sort_values() digunakan untuk mengurutkan kolom dalam Pandas dataframe berdasarkan nilai dalam urutan menaik atau menurun
#mengurutkan nilai dalam sepal length
bunga_csv.sort_values("sepal length (cm)")
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %%
#ascending parameter yang true secara default
#karena dia bernilai false maka data akan diurutkan dari yang terbesar ke yang terkecil
bunga_csv.sort_values("sepal length (cm)" , ascending=False)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 131                7.9               3.8                6.4               2.0
# 135                7.7               3.0                6.1               2.3
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# ..                 ...               ...                ...               ...
# 41                 4.5               2.3                1.3               0.3
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 13                 4.3               3.0                1.1               0.1
#
# [150 rows x 4 columns]

# %%
#mengurutkan data berdasarkan sepal length dan sepal width 
bunga_csv.sort_values(["sepal length (cm)" , "sepal width (cm)"])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 8                  4.4               2.9                1.4               0.2
# 38                 4.4               3.0                1.3               0.2
# 42                 4.4               3.2                1.3               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 118                7.7               2.6                6.9               2.3
# 122                7.7               2.8                6.7               2.0
# 135                7.7               3.0                6.1               2.3
# 117                7.7               3.8                6.7               2.2
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.4 Mengubah data pada Pandas
#
# Data yang telah dipanggil dapat dirubah sesuai dengan kebutuhan

# %%
#kita akan mengubah data petal length dengan *3.5
bunga_csv["petal length (cm)"] = 3.5*bunga_csv["petal length (cm)"]
print(bunga_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5               4.90               0.2
# 1                  4.9               3.0               4.90               0.2
# 2                  4.7               3.2               4.55               0.2
# 3                  4.6               3.1               5.25               0.2
# 4                  5.0               3.6               4.90               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0              18.20               2.3
# 146                6.3               2.5              17.50               1.9
# 147                6.5               3.0              18.20               2.0
# 148                6.2               3.4              18.90               2.3
# 149                5.9               3.0              17.85               1.8
#
# [150 rows x 4 columns]

# %%
#.drop disini berfungsi untuk men-delete sebuah kolom
#contohnya kita men-delete petal length
bunga_csv = bunga_csv.drop(columns = ["petal length (cm)"])
print(bunga_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal width (cm)
# 0                  5.1               3.5               0.2
# 1                  4.9               3.0               0.2
# 2                  4.7               3.2               0.2
# 3                  4.6               3.1               0.2
# 4                  5.0               3.6               0.2
# ..                 ...               ...               ...
# 145                6.7               3.0               2.3
# 146                6.3               2.5               1.9
# 147                6.5               3.0               2.0
# 148                6.2               3.4               2.3
# 149                5.9               3.0               1.8
#
# [150 rows x 3 columns]

# %%
#.iloc sedikit berbeda dengan mendrop berdasarkan indeks kolom pada cara kedua
#dengan cara ini, kita dapat memastikan bahwa kolom yang didrop adalah yang benar-benar kita ingin drop. Dengan asumsi kita ingin menghapus kolom pertama (indeks 0)
bunga_csv["petal length"] = bunga_csv.iloc[:,4:7].sum(axis=1)
print(bunga_csv)
# Out:
#      sepal length (cm)  sepal width (cm)  petal width (cm)  petal length
# 0                  5.1               3.5               0.2           0.0
# 1                  4.9               3.0               0.2           0.0
# 2                  4.7               3.2               0.2           0.0
# 3                  4.6               3.1               0.2           0.0
# 4                  5.0               3.6               0.2           0.0
# ..                 ...               ...               ...           ...
# 145                6.7               3.0               2.3           0.0
# 146                6.3               2.5               1.9           0.0
# 147                6.5               3.0               2.0           0.0
# 148                6.2               3.4               2.3           0.0
# 149                5.9               3.0               1.8           0.0
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.5 Menyimpan data menggunakan Pandas
#
# Data yang telah dirubah sesuai dengan keperluan dapat disimpan menjadi tiga bentuk file yaitu .txt, .xlsx dan .csv

# %%
#penyimpanan data pada csv
#data variabel yang disimpan dengan fungsi to_csv
#sep yang berfungsi sebagai pemisah dan defaultnya adalah spasi
#index=False digunakan untuk menunjukkan data ke csv tanpa index baris 
bunga_csv.to_csv("bunga_iris_baru.txt" ,index=False, sep = "\t")

# %%
#penyimpanan data pada csv
#data variabel yang disimpan dengan fungsi to_csv
#index=False digunakan untuk menunjukkan data ke csv tanpa index baris 
bunga_csv.to_csv("bunga_iris_baru.csv", index=False)

# %%
#penyimpanan data pada excel
#data variabel yang disimpan dengan fungsi to_csv
#index=False digunakan untuk menunjukkan data ke excel tanpa index baris 
bunga_csv.to_excel("bunga_iris_baru.xlsx", index=False)

# %%
#menggilan data csv dengan fungsi read_csv pada variabel data
data = pd.read_csv("bunga_iris_baru.txt")
print(data)
# Out:
#     sepal length (cm)\tsepal width (cm)\tpetal width (cm)\tpetal length
# 0                                   5.1\t3.5\t0.2\t0.0
# 1                                   4.9\t3.0\t0.2\t0.0
# 2                                   4.7\t3.2\t0.2\t0.0
# 3                                   4.6\t3.1\t0.2\t0.0
# 4                                   5.0\t3.6\t0.2\t0.0
# ..                                                 ...
# 145                                 6.7\t3.0\t2.3\t0.0
# 146                                 6.3\t2.5\t1.9\t0.0
# 147                                 6.5\t3.0\t2.0\t0.0
# 148                                 6.2\t3.4\t2.3\t0.0
# 149                                 5.9\t3.0\t1.8\t0.0
#
# [150 rows x 1 columns]

# %%
#delimiter='t' yang berfungsi sebagai pemisah dan defaultnya adalah spasi
data2 = pd.read_csv("bunga_iris_baru.txt" ,delimiter="\t")
print(data2)
# Out:
#      sepal length (cm)  sepal width (cm)  petal width (cm)  petal length
# 0                  5.1               3.5               0.2           0.0
# 1                  4.9               3.0               0.2           0.0
# 2                  4.7               3.2               0.2           0.0
# 3                  4.6               3.1               0.2           0.0
# 4                  5.0               3.6               0.2           0.0
# ..                 ...               ...               ...           ...
# 145                6.7               3.0               2.3           0.0
# 146                6.3               2.5               1.9           0.0
# 147                6.5               3.0               2.0           0.0
# 148                6.2               3.4               2.3           0.0
# 149                5.9               3.0               1.8           0.0
#
# [150 rows x 4 columns]

# %% [markdown]
# # 5.21.6 Menyaring data menggunakan Pandas
#
# Data yang telah dipanggil dapat disaring sesuai dengan kebutuhan analisis kedepannya

# %%
#digunakan untuk mencari baris di dataframe bunga_iris yang memiliki nilai kolom sepal length (cm) = 4.8 menggunakan metode .loc[]
#sehingga baris dengan nilai kolom sepal length (cm) = 4.8 
bunga_csv.loc[bunga_csv["sepal length (cm)"]== 4.8]
# Out:
#     sepal length (cm)  sepal width (cm)  petal width (cm)  petal length
# 11                4.8               3.4               0.2           0.0
# 12                4.8               3.0               0.1           0.0
# 24                4.8               3.4               0.2           0.0
# 30                4.8               3.1               0.2           0.0
# 45                4.8               3.0               0.3           0.0

# %%
#digunakan untuk mencari baris dataframe bunga_iris yang memiliki nilai sepal length (cm) = 5.0 menggunakan metode .loc[]
#dan kolom petal width(cm) = 0.2 
#serta operator logika dan (&) 
(bunga_csv.loc[(bunga_csv["sepal length (cm)"] == 5.0) &
                           (bunga_csv["petal width (cm)"] == 0.2)])
# Out:
#     sepal length (cm)  sepal width (cm)  petal width (cm)  petal length
# 4                 5.0               3.6               0.2           0.0
# 7                 5.0               3.4               0.2           0.0
# 25                5.0               3.0               0.2           0.0
# 35                5.0               3.2               0.2           0.0
# 49                5.0               3.3               0.2           0.0

# %%
#baris yang memenuhi syarat akan ditampilkan 
bunga_csv.loc[(bunga_csv['sepal length (cm)']== 5.0) &
                (bunga_csv['petal width (cm)'] == 0.2) &
                (bunga_csv['sepal width (cm)'] == 3.3)]
# Out:
#     sepal length (cm)  sepal width (cm)  petal width (cm)  petal length
# 49                5.0               3.3               0.2           0.0

# %% [markdown]
# # 5.21.7 Pengelompokan data menggunakan Pandas
#
# Data yang sama dapat dikelompokkan untuk analisis lebih lanjut

# %%
#pengelompokkan data dengan fungsi mean
#mean() berfungsi menghitung nilai rata-rata dari sebuah kolom numerik pada dataframe
bunga_csv.groupby(["petal width (cm)"]).mean()
# Out:
#                   sepal length (cm)  sepal width (cm)  petal length
# petal width (cm)
# 0.1                        4.820000          3.360000           0.0
# 0.2                        4.972414          3.379310           0.0
# 0.3                        4.971429          3.328571           0.0
# 0.4                        5.300000          3.785714           0.0
# 0.5                        5.100000          3.300000           0.0
# 0.6                        5.000000          3.500000           0.0
# 1.0                        5.414286          2.371429           0.0
# 1.1                        5.400000          2.466667           0.0
# 1.2                        5.780000          2.740000           0.0
# 1.3                        5.884615          2.746154           0.0
# 1.4                        6.325000          2.912500           0.0
# 1.5                        6.183333          2.816667           0.0
# 1.6                        6.375000          3.100000           0.0
# ...

# %%
#pengelompokkan data dengan fungsi mean
#mean() berfungsi menghitung nilai rata-rata dari sebuah kolom numerik di dataframe
#sort_values akan mengurutkan berdasarkan nilai terkecil ke terbesar dari data yang diminta
#ascending=True menentukan pengurutan sort_values dari nilai terkecil ke terbesar
bunga_csv.groupby(["petal width (cm)"]).mean().sort_values("sepal width (cm)" ,ascending=True)
# Out:
#                   sepal length (cm)  sepal width (cm)  petal length
# petal width (cm)
# 1.0                        5.414286          2.371429           0.0
# 1.1                        5.400000          2.466667           0.0
# 1.9                        6.340000          2.680000           0.0
# 1.2                        5.780000          2.740000           0.0
# 1.3                        5.884615          2.746154           0.0
# 1.7                        5.800000          2.750000           0.0
# 1.5                        6.183333          2.816667           0.0
# 1.4                        6.325000          2.912500           0.0
# 1.8                        6.400000          2.941667           0.0
# 2.0                        6.650000          3.016667           0.0
# 2.1                        6.916667          3.033333           0.0
# 2.3                        6.912500          3.087500           0.0
# 2.4                        6.266667          3.100000           0.0
# ...

# %%
#pengelompokkan data dengan fungsi sum
#sum() berfungsi untuk menghitung jumlah dari sebuah kolom numerik pada dataframe
bunga_csv.groupby(["petal width (cm)"]).sum()
# Out:
#                   sepal length (cm)  sepal width (cm)  petal length
# petal width (cm)
# 0.1                            24.1              16.8           0.0
# 0.2                           144.2              98.0           0.0
# 0.3                            34.8              23.3           0.0
# 0.4                            37.1              26.5           0.0
# 0.5                             5.1               3.3           0.0
# 0.6                             5.0               3.5           0.0
# 1.0                            37.9              16.6           0.0
# 1.1                            16.2               7.4           0.0
# 1.2                            28.9              13.7           0.0
# 1.3                            76.5              35.7           0.0
# 1.4                            50.6              23.3           0.0
# 1.5                            74.2              33.8           0.0
# 1.6                            25.5              12.4           0.0
# ...

# %%
#pengelompokkan data dengan fungsi count
#count() berfungsi untuk memanpilkan jumlah kolom dan baris pada inisial yang dituju
bunga_csv.groupby(["petal width (cm)"]).count()
# Out:
#                   sepal length (cm)  sepal width (cm)  petal length
# petal width (cm)
# 0.1                               5                 5             5
# 0.2                              29                29            29
# 0.3                               7                 7             7
# 0.4                               7                 7             7
# 0.5                               1                 1             1
# 0.6                               1                 1             1
# 1.0                               7                 7             7
# 1.1                               3                 3             3
# 1.2                               5                 5             5
# 1.3                              13                13            13
# 1.4                               8                 8             8
# 1.5                              12                12            12
# 1.6                               4                 4             4
# ...

# %% [markdown]
# # 5.22 Matplotlib
# Matplotlib merupakan salah satu Library pada Python yang fungsi utamanya
# adalah menggambarkan grafik, histogram dan berbagai jenis plot hasil
# dari pengolahan data menggunakan Library lainnya yaitu Pandas dan Numpy.
# Untuk itu penggunaan ketiga Library tersebut biasanya menjadi satu kesatuan

# %%
#memanggil ketiga jenis library 
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 5.22.1 Grafik sederhana dengan Matplotlib
# Pada dasarnya Matplotlib berfungsi untuk memplot data menjadi grafik, histogram atau bentuk lainnya untuk mempermudah visualisasi data yang sedang
# diolah

# %%
#ini adalah inisialisasi variabel berdasarkan kolom pada data yang diminta
x = bunga_csv ["sepal width (cm)"]
y = bunga_csv ["petal width (cm)"]

#plot berfungsi untuk menampilkan data koordinat kedalam garis koordinat 
plt.plot(x,y)

#title berfungsi untuk menamai koordinat
plt.title("Grafik sepal dan petal")

#label berfungsi untuk menamai sumbu yang dimaksud pada koordinat
plt.xlabel("X = panjang sepal")
plt.ylabel("Y = panjang petal")
# Out:
# Text(0, 0.5, 'Y = panjang petal')

# %% [markdown]
# # 5.22.2 Properti Pembuatan Grafik dengan Matplotlib
# Untuk memperjelas keterangan pada grafik, ada banyak properti yang bisa dimanfaatkan pada Matplotlib

# %%
#ini adalah inisialisasi variabel dengan data variabel sesuai inisialisasi kolom yang dituju
x = bunga_csv ["sepal length (cm)"]
y = bunga_csv ["petal length (cm)"]
x1 = bunga_csv ["sepal width (cm)"]
y1 = bunga_csv["petal width (cm)"]

#pembentukan sumbu koordinat yang berukuran 13 x 13 inch dan resolusi gambar 300 dpi
#figure() berfungsi untuk menentukan gambar dengan format inci
#figsize() berfungsi  untuk menentukan ukuran gambar dengan format inci
#dpi berfungsi untuk menentukan resolusi gambar dalam piksel per inci
plt.figure(figsize=(13,13), dpi=300) 

#label berfungsi untuk memberi label atau judul pada plot
#color berfungsi untuk memberi warna pada plot
#linewidth berfungsi untuk ketebalan garis pada plot
#marker berfungsi untuk menandai titik pada plot
#makersize berfungsi unutuk menentukan ukuran dari marker 
#markeredgecolor berfungsi untuk memberi warna pada tepi marker
#linestyle berfungsi untuk menentukan jenis garis pada plot
plt.plot(x,y, label = "Grafik length" ,  color = "pink" , 
         linewidth = 2 , marker = "*" , markersize = 15 , 
         markeredgecolor = "green" , linestyle="-")

#ini untuk membuat plot dari data pada variabel x1 dan y1
#plot ini tidak memiliki variabel lain 
#seperti label ataupun color sehingga plot ini akan menggunakan nilai default untuk setiap parameter
plt.plot(x1,y1, label = "Garik width", marker = "*" , 
         markersize = 15 , markeredgecolor = "blue" )

#penamaan koordinat dengan fungsi title()
#title() berfungsi untuk memasukan data string dan ukuran font
#fontdict berfungsi untuk menentukan ukuran font
plt.title("Grafik Bunga Iris ", fontdict = {"fontname" : "Sans Serif" , "fontsize" : 12})

#inisialisasi sumbu x dan y dengan penamaan menggunakan data string
#fontdict berfungsi untuk menentukan ukuran font
plt.xlabel("X", fontdict={"fontname" : "Sans Serif" , "fontsize" : 6})
plt.ylabel("Y", fontdict={"fontname" : "Sans Serif" , "fontsize" : 6})

#pembentukan output dari label x dan y
plt.xticks(bunga_csv["sepal length (cm)"])
plt.yticks(bunga_csv["petal length (cm)"])
plt.legend()

#pembentukan output dari label x1 dan y1
plt.xticks(bunga_csv["sepal width (cm)"])
plt.yticks(bunga_csv["petal width (cm)"])
plt.legend()

#penyimpanan figure pada grafik.png dengan resolusi 300 dpi
plt.savefig("grafik.png" , dpi=300)

#show() berfungsi untuk mengeluarkan output figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal length (cm)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # 5.22.3 Histogram sederhana dengan Matplotlib

# %%
#ini adalah inisialisasi variabel dengan menginput data yang dituju sesuai dengan kolom yang diminta
sepal = bunga_csv["sepal length (cm)"]
petal = bunga_csv["petal length (cm)"]

#namun terdapat operator perbandingan sebagai pengelompokan data kolom yang diminta
sepal1 = bunga_csv["sepal width (cm)"]
petal1 = bunga_csv["petal width (cm)"]

#ini adalah inisialisasi sumbu x dan y 
#fontdict berfungsi untuk menentukan ukuran font
plt.xlabel("Sepal (cm)")
plt.ylabel("Petal (cm)")

#bar() berfungsi untuk membentuk histogram
print(plt.bar(sepal,sepal1))
print(plt.bar(petal,petal1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal length (cm)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # 5.22.4 Properti Pembuatan Histogram dengan Matplotlib
# Berbagai properti pembuatan histogram dengan menggunakan Matplotlib

# %%
#inisialisasi variabel dengan menginput data integer
x = [-5,-3,-1,0,1,3,5,6]
y = [31,13,3,1,1,7,21,31]

#figure() berfungsi untuk menentukan gambar dengan format inci
#figsize() berfungsi  untuk menentukan ukuran gambar dengan format inci
plt.figure(figsize=(3,3))

#inisialisasi variabel dengan fungsi bar() beserta menentukan warnanya
hist = plt.bar(x,y,color='purple')
pola = ["x","x","x","x","/","/","/","/"]

#for berfungsi untuk mengurutkan variabel hist
for bar in hist :
    #set_hatch() berfungsi untuk pola di dalam batang
    bar.set_hatch(pola.pop(0))

#show() berfungsi untuk mengeluarkan output figure
plt.show()
